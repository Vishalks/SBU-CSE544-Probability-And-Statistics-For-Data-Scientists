# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import scipy.stats as stats
import math
def drawNormalPlot(mean, variance, row, std_dev):
  sigma = math.sqrt(variance)
  x = np.linspace(mean - 4*sigma, mean + 4*sigma, 100)
  plt.plot(x, stats.norm.pdf(x, mean, sigma), label = "R" + str(row+1) + " Mean:" 
           + str(round(mean,2)) + " Var:" + str(round(variance, 2)))  
  plt.xlabel('X_i')
  plt.ylabel('Posterior')
  plt.title('Bayesian Posterior distributions for sigma=' + str(std_dev))

# %%
def plotBayesianDistributions(all_data, sigma):
  a = 0
  b_square = 1
  table = pd.DataFrame(columns=['Mean', 'Variance'])
  for i, row in all_data.iterrows():  
    data = row
    n = data.size
    x_bar = data.mean()
    se_square = (sigma * sigma) / n
    x = (b_square * x_bar + se_square * a) / (b_square + se_square)
    y_square = (b_square * se_square) / (b_square + se_square)
    table = table.append({'Mean': x, 'Variance': y_square}, ignore_index=True)
    # print("n = ", n, " x_bar=", x_bar, " se_square=", se_square, " x = ", x)
    drawNormalPlot(x, y_square, i, sigma)
    a = x
    b_square = y_square
  print(table)
  plt.legend(loc="best")
  plt.show()

# %% [markdown]
# # Answer 2a

# %%
sigma3 = pd.read_csv("q2_sigma3.txt", header = None)

# %%
sigma3
# Out:
#          0         1         2   ...        97        98        99
# 0  5.205805  5.411719  6.021217  ...  4.362651  4.215081  4.703919
# 1  6.221919  2.854502  4.821436  ...  5.411097  4.965547  6.387569
# 2  4.102768  4.467349  4.972755  ...  4.042282  2.575606  5.929412
# 3  6.155258  4.975282  5.203738  ...  5.467308  4.592731  5.870239
# 4  6.947777  5.308392  5.181037  ...  2.956324  4.970756  5.614556
#
# [5 rows x 100 columns]

# %%
plotBayesianDistributions(sigma3, 3)
# Out:
#        Mean  Variance
# 0  4.590762  0.082569
# 1  4.813524  0.043062
# 2  4.921257  0.029126
# 3  4.972837  0.022005
# 4  4.983966  0.017682

# %% [markdown]
# # Answer 2b

# %%
sigma100 = pd.read_csv("q2_sigma100.txt", header = None)

# %%
sigma100
# Out:
#           0          1          2   ...         97         98         99
# 0  18.238717  17.113829 -32.533941  ...  -1.353982  14.075647   8.318957
# 1  14.404512 -25.276252  12.142635  ...   5.339352  -4.896798  -3.159909
# 2  -6.871398  23.162237  -0.532527  ... -28.691718  -1.296639  15.685130
# 3  21.966540  12.512560  -3.079387  ...  -8.604308   5.708755   9.039434
# 4  25.953780  10.903817  20.867280  ...  36.789712  16.856859 -15.283521
#
# [5 rows x 100 columns]

# %%
plotBayesianDistributions(sigma100, 100)
# Out:
#        Mean  Variance
# 0  0.058716  0.990099
# 1  0.095009  0.980392
# 2  0.138226  0.970874
# 3  0.171219  0.961538
# 4  0.218918  0.952381
